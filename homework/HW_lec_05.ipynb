# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def Simpson1(start, end, parts,integer1, power1,integer2, power2,integer3,plot=1):
    """
    Simpson sum rule
    
    """
    #define the function
    f = lambda x: integer1*x**power1+integer2*x**power2 + integer3 
    
    #define the X, Y points 
    deltax = (end - start) / parts
    resultsx = np.linspace(start, end, parts+1)
    resultsy = f(resultsx)

    #-----------------------------------------------------
    #define the Simpson points and calculate the area here
    #-----------------------------------------------------
    area = []

    #By default, we also output the plot.
    if plot==1:
        x = np.linspace(start,end,100)
        y = f(x)        
        plt.plot(x, y, 'r')
        
        #-----------------------------------------------------
        #draw the curves based on Simpson points here
        #-----------------------------------------------------             
    
        plt.xlim([start,end])
        plt.ylim([min(y),max(y)])
        plt.show()
    
    return sum(area)

def Simpson2(start, end, parts,integer1, power1,integer2, power2,integer3,plot=1):
    """
    Simpson sum rule
    
    """
    #define the function
    e=2.718281828459045
    f = lambda x: e**(integer1*x**power1) 
    
    #define the X, Y points 
    deltax = (end - start) / parts
    resultsx = np.linspace(start, end, parts+1)
    resultsy = f(resultsx)

    #-----------------------------------------------------
    #define the Simpson points and calculate the area here
    #-----------------------------------------------------
    area = []

    #By default, we also output the plot.
    if plot==1:
        x = np.linspace(start,end,100)
        y = f(x)        
        plt.plot(x, y, 'r')
        
        #-----------------------------------------------------
        #draw the curves based on Simpson points here
        #-----------------------------------------------------             
    
        plt.xlim([start,end])
        plt.ylim([min(y),max(y)])
    
    return sum(area)
Simpson1(0,3,100,1,2,-1,1,1)
Simpson1(0,3,100,1,4,-1,1,1)
Simpson2(0,3,100,-1,2,0,0,0)
# Out:
# 0

# %%
# Out:
# 1 + 2
